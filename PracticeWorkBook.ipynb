# %% [markdown]
# <a href="https://colab.research.google.com/github/Honey-Dev9042/Python-GenAI-Training-Content/blob/Develop-training_content/PracticeWorkBook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**This is my Hello to the GenAI enthusiat all across the World**
#
# ###We will Conqueror it to the finest level

# %%
print("Hello Coding World")
# Out:
# Hello Coding World

# %% [markdown]
# #**Declaring a Variable**

# %%
BD = "Ram is a My Friend"

# %% [markdown]
# **Calling Variable**

# %%
print(BD)
# Out:
# Ram is a My Friend

# %% [markdown]
# **Same Example but this time Numeric**

# %%
Roop = 100

# %%
print("Roopal has Score of =" ,Roop,"in physical Chemistry"+ "!" )
# Out:
# Roopal has Score of = 100 in physical Chemistry!

# %%
"user_name = input("Hi Agent, what is your name? ")
print(f"Hello {user_name}, Good morning! How can I help you?")
# Out:
# Hi Agent, what is your name? Honey Sharma
# Hello Honey Sharma, Good morning! How can I help you?
